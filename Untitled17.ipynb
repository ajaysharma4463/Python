# %%
print("day12")
print("pratice for mathematics and programing ")
# Out:
# day12
# pratice for mathematics and programing

# %%
import turtle
import time

print(turtle.forward(222))   # will will execute in other window
print(turtle.right(222))
print(time.sleep(4))
# Out:
# None
# None
# None

# %%
import turtle
import time

 # will will execute in other window
turtle.right(222)
turtle.forward(90)
time.sleep(4)
turle.done()

# %%
from turtle import forward,right,done,left,circle   #  we write like this : from turtle import *
from time import sleep

circle(180)
left(90)
sleep(4)
done()

# %%
print("hi")
# Out:
# hi

# %%
print(dir())
for i in dir():
    print(i)
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'circle', 'done', 'exit', 'forward', 'get_ipython', 'left', 'quit', 'right', 'sleep', 'turtle']
# In
# Out
# _
# __
# ___
# __builtin__
# __builtins__
# __doc__
# __loader__
# __name__
# __package__
# __spec__
# _dh
# _i
# _i1
# _i10
# _i11
# _i12
# _i13
# _i14
# _i15
# _i2
# _i3
# _i4
# _i5
# _i6
# _i7
# _i8
# _i9
# _ih
# _ii
# _iii
# _oh
# circle
# done
# exit
# forward
# get_ipython
# left
# quit
# right
# sleep
# turtle

# %%
print(__builtins__)
for i in dir(__builtins__):
    print("hi"+i)
# Out:
# <module 'builtins' (built-in)>
# hiArithmeticError
# hiAssertionError
# hiAttributeError
# hiBaseException
# hiBlockingIOError
# hiBrokenPipeError
# hiBufferError
# hiBytesWarning
# hiChildProcessError
# hiConnectionAbortedError
# hiConnectionError
# hiConnectionRefusedError
# hiConnectionResetError
# hiDeprecationWarning
# hiEOFError
# hiEllipsis
# hiEnvironmentError
# hiException
# hiFalse
# hiFileExistsError
# hiFileNotFoundError
# hiFloatingPointError
# hiFutureWarning
# hiGeneratorExit
# hiIOError
# hiImportError
# hiImportWarning
# hiIndentationError
# hiIndexError
# hiInterruptedError
# hiIsADirectoryError
# hiKeyError
# hiKeyboardInterrupt
# hiLookupError
# hiMemoryError
# hiModuleNotFoundError
# hiNameError
# hiNone
# hiNotADirectoryError
# hiNotImplemented
# hiNotImplementedError
# hiOSError
# hiOverflowError
# hiPendingDeprecationWarning
# hiPermissionError
# hiProcessLookupError
# hiRecursionError
# hiReferenceError
# hiResourceWarning
# hiRuntimeError
# hiRuntimeWarning
# ...
