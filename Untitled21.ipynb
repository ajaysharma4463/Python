# %%
print("day 25 in numpy")
# Out:
# day 25 in numpy

# %%
import numpy as np
x=np.random.random((10000,1))    # random will produce 0 to 1 rwsult in float
x
np.mean(x)
# Out:
# 0.4983755992090978

# %%
a=np.array(((1,2,3,4),(2,3,4,5)))
b=np.array(((12,22,32,24),(2,23,24,25)))
c=a-b
c
# Out:
# array([[-11, -20, -29, -20],
#        [  0, -20, -20, -20]])

# %%
c1=np.subtract(a,b,dtype='int32')  # another way to doing it
c1
# Out:
# array([[-11, -20, -29, -20],
#        [  0, -20, -20, -20]])

# %%
c1=np.multiply(a,b,dtype='int32')  # another way to doing it
c1
# Out:
# array([[ 12,  44,  96,  96],
#        [  4,  69,  96, 125]])

# %%
m=np.matmul(a,b)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f7e64e034f7e> in <module>
# ----> 1 m=np.matmul(a,b)
#       2 m
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 4)
