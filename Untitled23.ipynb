# %%
print("process of cleaning data is called data munging or data wrangling")
# Out:
# process of cleaning data is called data munging or data wrangling

# %%
print("first we need to load the data with read.csv method ")
print("we can work with excel sometime but sometime it give wrong answer ")
# but when the data is null or empty ,excel it work properly with data
# df['Temperature'].max()   # for maximun
# df.fillna(0,inplace=True) is used for put 0 value in empty data or null value 

# if you donot  have anaconda then just install pip in command prompt
# pip install pandas
# then we can

# %%
print("dataframes is very important in pandas , we will be using it very offen")
print("dataframe is a object of pandas ,it represent data with row and column like tabular form or excel sheet")

# lets create dictionary
dic ={
    'name':['Ajay','Amit','Anurag'],
    'marks':[12,12,23]
}

dic
# Out:
# dataframes is very important in pandas , we will be using it very offen
# dataframe is a object of pandas ,it represent data with row and column like tabular form or excel sheet
# {'name': ['Ajay', 'Amit', 'Anurag'], 'marks': [12, 12, 23]}

# %%
import pandas as pd
df=pd.DataFrame(dic)
print(df)
# Out:
#      name  marks
# 0    Ajay     12
# 1    Amit     12
# 2  Anurag     23

# %%
dic ={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'ecent':['rain','sunny','snow','snow','rain','sunny']
}

dic
# Out:
# {'day': ['1/1/2017',
#   '1/2/2017',
#   '1/3/2017',
#   '1/4/2017',
#   '1/5/2017',
#   '1/6/2017'],
#  'temperature': [32, 35, 28, 24, 32, 31],
#  'windspeed': [6, 7, 2, 7, 4, 2],
#  'ecent': ['rain', 'sunny', 'snow', 'snow', 'rain', 'sunny']}

# %%
import pandas as pd
df=pd.DataFrame(dic)
df
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df.shape   # it is in tuple form
# Out:
# (6, 4)

# %%
row,column=df.shape   # we can store tuuple in row variables as well
row
# Out:
# 6

# %%
df.head()   # bydeafult it print first 5 records , to avoid to print all data everytime
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny

# %%
df.tail()
# Out:
#         day  temperature  windspeed  ecent
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df.tail(3)
# Out:
#         day  temperature  windspeed  ecent
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df[1:3]
# Out:
#         day  temperature  windspeed  ecent
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow

# %%
df[::]
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df[:]
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df[::2]
# Out:
#         day  temperature  windspeed ecent
# 0  1/1/2017           32          6  rain
# 2  1/3/2017           28          2  snow
# 4  1/5/2017           32          4  rain

# %%
df[::-2]
# Out:
#         day  temperature  windspeed  ecent
# 5  1/6/2017           31          2  sunny
# 3  1/4/2017           24          7   snow
# 1  1/2/2017           35          7  sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'ecent'], dtype='object')

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a0fe53b7fddd> in <module>
# ----> 1 df.row
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['day']   # same thing
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df.day)   # pandas series
# Out:
# pandas.core.series.Series

# %%
df[['day','day','temperature']]   # use doub cortes
# Out:
#         day       day  temperature
# 0  1/1/2017  1/1/2017           32
# 1  1/2/2017  1/2/2017           35
# 2  1/3/2017  1/3/2017           28
# 3  1/4/2017  1/4/2017           24
# 4  1/5/2017  1/5/2017           32
# 5  1/6/2017  1/6/2017           31

# %%
df['day']    # this will not give heading of column
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['day'].max()
# Out:
# '1/6/2017'

# %%
df['day'].min()
# Out:
# '1/1/2017'

# %%
df.day.min()
# Out:
# '1/1/2017'

# %%
df.temperature.min()
# Out:
# 24

# %%
df.temperature.min()
# Out:
# 24

# %%
df.temperature.std()  # standard deviation
# Out:
# 3.8297084310253524

# %%
df.describe()   #only pic two column becasue i have two column which have integer type
# by default it will print 8  different result
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
# now we can also work or think like sql 
df.temperature>=22   # it reture boolean result
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: temperature, dtype: bool

# %%
df[df.temperature>=33]
# Out:
#         day  temperature  windspeed  ecent
# 1  1/2/2017           35          7  sunny

# %%
df
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df.temperature.max()  #  this will print maxminum result
# Out:
# 35

# %%
df[df.temperature==df.temperature.max()]   # same thing but with row
# Out:
#         day  temperature  windspeed  ecent
# 1  1/2/2017           35          7  sunny

# %%
# difference beween df['temperature'] and df.temperature is  when we have column name have spaces in beteen like ='temp now'
# in this variable have spaces so we have to use df['temp now']      very very very importnt

# %%
# we can select which column we want or not
df[df.temperature==df.temperature.min()]
# Out:
#         day  temperature  windspeed ecent
# 3  1/4/2017           24          7  snow

# %%
df[['day']][df.temperature==df.temperature.min()]
# Out:
#         day
# 3  1/4/2017

# %%
df[['day','temperature']][df.temperature==df.temperature.min()]
# Out:
#         day  temperature
# 3  1/4/2017           24

# %%
#  https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html
# read it
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')   # it doesnot modift the oridinal dat ,it is new df so e have to use inplace method
# Out:
#           temperature  windspeed  ecent
# day
# 1/1/2017           32          6   rain
# 1/2/2017           35          7  sunny
# 1/3/2017           28          2   snow
# 1/4/2017           24          7   snow
# 1/5/2017           32          4   rain
# 1/6/2017           31          2  sunny

# %%
df.set_index('day',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-c3d66166ad41> in <module>
# ----> 1 df.set_index('day',inplace=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['day'] are in the columns"

# %%
df
# Out:
#           temperature  windspeed  ecent
# day
# 1/1/2017           32          6   rain
# 1/2/2017           35          7  sunny
# 1/3/2017           28          2   snow
# 1/4/2017           24          7   snow
# 1/5/2017           32          4   rain
# 1/6/2017           31          2  sunny

# %%
df.loc['1/1/2017']    # it will print all data
# Out:
# temperature      32
# windspeed         6
# ecent          rain
# Name: 1/1/2017, dtype: object

# %%
# we can rest the table as well
df.reset_index()
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df.reset_index(inplace=True)  # same thing

# %%
df
# Out:
#         day  temperature  windspeed  ecent
# 0  1/1/2017           32          6   rain
# 1  1/2/2017           35          7  sunny
# 2  1/3/2017           28          2   snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   rain
# 5  1/6/2017           31          2  sunny

# %%
df.set_index('ecent',inplace=True)   # it is duplicate value  # it is correct code okokokok
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-c2e38c2a95b4> in <module>
# ----> 1 df.set_index('ecent',inplace=True)   # it is duplicate value
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['ecent'] are in the columns"

# %%
df.loc['snow']
# Out:
#             day  temperature  windspeed
# ecent
# snow   1/3/2017           28          2
# snow   1/4/2017           24          7
