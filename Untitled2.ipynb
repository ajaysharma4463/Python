# %%
# day 2
print("day 2 ajay")
# Out:
# day 2 ajay

# %%
print("Escape character ")
# Out:
# Escape character

# %%
splitstring='this string will split in half\n  will agian'
print(splitstring)
# Out:
# this string will split in half

# %%
print(splitstring)
# Out:
# this string will split in half

# %%
splitstring='this string will split in half \n  will agian \n again'
print("splitstring")
# Out:
# splitstring

# %%
print(splitstring)
# Out:
# this string will split in half
#   will agian
#  again

# %%
splitstring2='will it print\nand \nagain\n'
print(splitstring2)
# Out:
# will it print
# and
# again

# %%
splitstring2='will it print \n and \n again \n'
print(splitstring2)
# Out:
# will it print
#  and
#  again

# %%
splitstring='this string will split in half\n  will agian'
print(splitstring)
# Out:
# this string will split in half
#   will agian

# %%
tabstring='now iam gonna tab the data lets check it out \t17\t03\t1995'
print(tabstring)
# Out:
# now iam gonna tab the data lets check it out 	17	03	1995

# %%
tabstring='now iam gonna tab the data lets check it out \t17 \t03\ t1995'
print(tabstring)
# Out:
# now iam gonna tab the data lets check it out 	17 	03\ t1995

# %%
triple_string="""this will break data in 3 set """
print(triple_string)
# Out:
# this will break data in 3 set

# %%
triple_string="""this will 

break data in 3 
set """
print(triple_string)
# Out:
# this will
#
# break data in 3
# set

# %%
triple_string="""this will break  \data \in 3 set """
print(triple_string)
# Out:
# this will break  \data \in 3 set

# %%
triple_string="""this will\
break data in 3\
set """
print(triple_string)
# Out:
# this willbreak data in 3set

# %%
triple_string="""this will break \
data in \
3 set """
print(triple_string)
# Out:
# this will break data in 3 set

# %%
triple_string="""this will\
break data in 3 set """
print(triple_string)
# Out:
# this willbreak data in 3 set

# %%
triple1="""this is triple data and my fiend said""hi,how are you'winking'" """"
print(triple1)
# Out:
#   File "<ipython-input-18-32046147bf33>", line 1
#     triple1="""this is triple data and my fiend said""hi,how are you'winking'" """"
#                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
triple1="""this is triple data and my fiend said"hi,how are you'winking'" """"
print(triple1)
# Out:
#   File "<ipython-input-19-f11901193f98>", line 1
#     triple1="""this is triple data and my fiend said"hi,how are you'winking'" """"
#                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
triple1="""this is triple data and my fiend said "hi,how are you'winking'". """"
print(triple1)
# Out:
#   File "<ipython-input-20-7b9abbdf254b>", line 1
#     triple1="""this is triple data and my fiend said "hi,how are you'winking'". """"
#                                                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
triple1=""" will print"again". """"
print(triple1)
# Out:
#   File "<ipython-input-21-614a9c5318c3>", line 1
#     triple1=""" will print"again". """"
#                                        ^
# SyntaxError: EOL while scanning string literal

# %%
triple1="""this is triple data and my fiend said """"
print(triple1)
# Out:
#   File "<ipython-input-22-61acc067fb84>", line 1
#     triple1="""this is triple data and my fiend said """"
#                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
triple1="""this is triple data and my fiend said"hi,how are you'winking'" """
print(triple1)
# Out:
# this is triple data and my fiend said"hi,how are you'winking'"

# %%
path1='C:\users\tablue.txt'
path2='C:\\users\\tablue.txt'
path3=r'C:\users\tablue.txt'
print(path1)
print(path2)
print(path3)
# Out:
#   File "<ipython-input-24-7f46e0e858f4>", line 1
#     path1='C:\users\tablue.txt'
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape

# %%
path1='C:\users\tablue.txt'
path2='C:\\users\\tablue.txt'
path3=r'C:\users\tablue.txt'
print(path1)
print(path2)
print(path3)
# Out:
#   File "<ipython-input-25-d64cce4dc336>", line 1
#     path1='C:\users\tablue.txt'
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape

# %%
print(r'C:\users\tablue.txt')
# Out:
# C:\users\tablue.txt

# %%
print('C:\users\tablue.txt')
# Out:
#   File "<ipython-input-27-45f7ae1254d6>", line 1
#     print('C:\users\tablue.txt')
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape

# %%
print('C:\\users\\tablue.txt')
# Out:
# C:\users\tablue.txt

# %%
# THIS THING WIL WORK ON PRINT NOT VALRIABE
#how to find out which varible is strong what
name='ajay'
status='single'
age=24

print(type(name))
print(type(status))
print(type(age))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
print(type())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-93652874d1da> in <module>
# ----> 1 print(type())
#
# TypeError: type() takes 1 or 3 arguments

# %%
#ow we gonna reboung the value of age ..lets check it out
age='23 yesrs'
print(age)
print(type(age))
# Out:
# 23 yesrs
# <class 'str'>

# %%
# now it is bound to string
print(name+'is'+age+'old')
# Out:
# ajayis23 yesrsold

# %%
print(name+' is '+age+'old')
# Out:
# ajay is 23 yesrsold

# %%
print(name+' is '+age+' old ')
# Out:
# ajay is 23 yesrs old

# %%
age=2
print(name+' is '+age+'old')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-717c2e1e02ac> in <module>
#       1 age=2
# ----> 2 print(name+' is '+age+'old')
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(name+' is '+'old')
# Out:
# ajay is old

# %%
print(name+' is '+'old'+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-eb0f02226d44> in <module>
# ----> 1 print(name+' is '+'old'+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(age)
# Out:
# 2

# %%
print(name+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-cd962d0a0605> in <module>
# ----> 1 print(name+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# its means varible should have string data in print funcrion otherwise it wil produce error
