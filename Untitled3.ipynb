# %%
#day 3
print('hi ,3rd day
      ')
# Out:
#   File "<ipython-input-1-079cb58cc883>", line 2
#     print('hi ,3rd day
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
print("3rd day")
# Out:
# 3rd day

# %%
# numeric data type in python
print("numeric,iteration,sequnce,mapping,file,class,exception")
# Out:
# numeric,iteration,sequnce,mapping,file,class,exception

# %%
print("sequence means string'str'")
# Out:
# sequence means string'str'

# %%
print("python 3 has three numeric data type :int,float,complex,,,,and python 2had long datatype instead of int becasue it doesnot store large valuebut in python 3 has int")
# Out:
# python 3 has three numeric data type :int,float,complex,,,,and python 2had long datatype instead of int becasue it doesnot store large valuebut in python 3 has int

# %%
print("we come from C++ to python and unlike other language pyton has no size limit in int data type")
# Out:
# we come from C++ to python and unlike other language pyton has no size limit in int data type

# %%
a=12
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 15
# 9
# 36
# 4.0
# 4
# 0

# %%
print("sometime  integer can give float result like a/b   but we can convert into  in integer datatype")
# Out:
# sometime  integer can give float result like a/b   but we can convert into  in integer datatype

# %%
for i in range(1,4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(2,2):
    print(i)

# %%
for i in range(2,3):
    print(i)
# Out:
# 2

# %%
print("in for loop python expect integger value only otherwise it will ve error")
# Out:
# in for loop python expect integger value only otherwise it will ve error

# %%
for i in range(1,a/b):     # it will return float result so it will give error let check it out
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9d4d512f82b7> in <module>
# ----> 1 for i in range(1,a/b):     # it will return float result so it will give error let check it out
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
for i in range (1,a//b):
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(10,1):
    print(i)

# %%
for i in range(-1,0):
    print(i)
# Out:
# -1

# %%
# so python dor=es not move backward it alwasys in ascending order

print(a-b)   # it is expression in python
# Out:
# 9

# %%
#variables are nnot expression becasue  it bound the value 
i=1
print(i)
i=2
print(i)
i=3
print(i)
# Out:
# 1
# 2
# 3

# %%
# we got the same result but it is not expresion 
print("precedence means priority")
# Out:
# precedence means priority

# %%
parrot="ajaysharmapakkaparo"
print(parrot)
print(parrot[9])
# Out:
# ajaysharmapakkaparo
# a

# %%
print("its means we can exteract he vaslaue from string ")
# Out:
# its means we can exteract he vaslaue from string

# %%
print(parrot[14])
# Out:
# a

# %%
print(parrot[11])
# Out:
# a

# %%
print(parrot[12])
# Out:
# k

# %%
task="Norwegian Blue"
print(task)
# Out:
# Norwegian Blue

# %%
print(task[3:5])
# Out:
# we

# %%
print(task[3:5],task[3,6,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e6e9b1d7e03e> in <module>
# ----> 1 print(task[3:5],task[3,6,8])
#
# TypeError: string indices must be integers

# %%
print(task[3:5],task[3:5)
# Out:
#   File "<ipython-input-28-b4c32e9d9de4>", line 1
#     print(task[3:5],task[3:5)
#                             ^
# SyntaxError: invalid syntax

# %%
print(task[3:5],task[3:5])
# Out:
# we we

# %%
print(task[3:5],task[3],task[6],task[8])
# Out:
# we w i n

# %%
for i in range(1,14):
    task[i]

# %%
for i in range(1,14):
    print(task[i])
# Out:
# o
# r
# w
# e
# g
# i
# a
# n
#
# B
# l
# u
# e

# %%
for i in range(0,14):
    print(task[i])
# Out:
# N
# o
# r
# w
# e
# g
# i
# a
# n
#
# B
# l
# u
# e

# %%
print(task[3:])
# Out:
# wegian Blue

# %%
print(task[4:9])
# Out:
# egian

# %%
print(task[-11])
print(task[-10])
print(task[-5])
print(task[-11])
print(task[-8])
print(task[-6])
# Out:
# w
# e
#
# w
# i
# n

# %%
print(3-14)
# Out:
# -11

# %%
print(task[3-14])
# Out:
# w

# %%
print("we can also work like this ")
# Out:
# we can also work like this

# %%
print(task[0:9])
print(task[:9])
# Out:
# Norwegian
# Norwegian

# %%
print(task[10:14])
print(task[10:])
# Out:
# Blue
# Blue

# %%
print(task[:6]+task[6:])
# Out:
# Norwegian Blue

# %%
print(task[:6] "" task[6:])
# Out:
#   File "<ipython-input-43-7c3efbfba219>", line 1
#     print(task[:6] "" task[6:])
#                     ^
# SyntaxError: invalid syntax

# %%
print(parrot[:])
# Out:
# ajaysharmapakkaparo

# %%
print(task[:])
# Out:
# Norwegian Blue
