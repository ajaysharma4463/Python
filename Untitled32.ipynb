# %%
# polynomial regression

y=mx+c is linear regression
y=m1x1+m2x2+...+C is multiple linear regression
y=m1x1+m2(x1)^2+m2(x1)^3+...+C polynomail regression

#when our points are like (1,2) (2,4) (3,8)  meaas parbolic then we use polynomial regression
# we use in like deaces spreeding


# why it is linear
linear meas coefficent 
nomlinear means   coeffiecit x2/coefficient x3

# %% [markdown]
# # polynomail regression  by udemy

# %%
it is not linear regresion ,svr and deacion tree

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("filename")
#examlle will be salary detector of employee becasue salary increase on the basis of position
x=dataset.iloc[:,1].values
y=dataset.iloc[:,2].values

# we donot need to use feature scslling just like linear refression
# and in this we do not need  to split the data into train set and tet set
# so we dont ise the library of sklear.cross_validation with train_test_split model

# %%
#fitting linear regression to the dataset

from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)

# %%
#fitting polynomail regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
x_poly=poly_reg.fit_tranform(x)
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y)
