# %%
ipaddress=input("enter id adress")
print(ipaddress.count("."))
# Out:
# enter id adress1.1.11..11.
# 5

# %%
ipaddress=input("enter id adress")
print(ipaddress.count())
# Out:
# enter id adressq2.2.2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-63884c2a5520> in <module>
#       1 ipaddress=input("enter id adress")
# ----> 2 print(ipaddress.count())
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
#  day 10

ipaddress=input("enter id adress")
print(ipaddress)
# Out:
# enter id adress222..2.
# 222..2.

# %%
print("list demostation")
# Out:
# list demostation

# %%
list=["love","cake","cool","name"]
for i in list:
    print("i love " +i)
# Out:
# i love love
# i love cake
# i love cool
# i love name

# %%
even=[2,4,6,8]
odd=[1,3,5,7]
number=even+odd
print(number)
# Out:
# [2, 4, 6, 8, 1, 3, 5, 7]

# %%
number.append("4")

# %%
print(number)
# Out:
# [2, 4, 6, 8, 1, 3, 5, 7, '4']

# %%
number.append(99)
print(number)
# Out:
# [2, 4, 6, 8, 1, 3, 5, 7, '4', 99]

# %%
print("list can a any sequce in numberical and charater")
number.append(99)
print(number)
# Out:
# list can a any sequce in numberical and charater
# [2, 4, 6, 8, 1, 3, 5, 7, '4', 99, 99]

# %%
print("data can be duplicate in list and it started with []")
# Out:
# data can be duplicate in list and it started with []

# %%
number.remove("4")
number.sort()
print(number)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e4379a062c70> in <module>
# ----> 1 number.remove("4")
#       2 number.sort()
#       3 print(number)
#
# ValueError: list.remove(x): x not in list

# %%
data=[1,2,45,3,2]
print(data)
data.append(33)
# Out:
# [1, 2, 45, 3, 2]

# %%
print(data)
data.sort()
print(data)
# Out:
# [1, 2, 45, 3, 2, 33]
# [1, 2, 2, 3, 33, 45]

# %%
print(data)
#data.sort()
print(data.sort())    # in python  sort with nor use with print ,othrwise eller
# Out:
# [1, 2, 2, 3, 33, 45]
# None

# %%
print(sorted(data))   # sorted function will produce correct data
# Out:
# [1, 2, 2, 3, 33, 45]

# %%
datanew=sorted(data)

# %%
if data==datanew:
    print("list is equal")
else:
    print("list is not equal")
# Out:
# list is equal

# %%
data.append(4)
if data==datanew:
    print("list is equal")
else:
    print("list is not equal")
# Out:
# list is not equal

# %%
list_1=[]
list_2=List()   # list constructor

print(list_1 +list_2)

if list_1==list_2:
    print("list are eual")

# %%
print(List("hi i am back"))  # output is incoorect but out will be:['h','i'......so on]  it will be lsit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-8058d842eff7> in <module>
# ----> 1 print(List("hi i am back"))
#
# NameError: name 'List' is not defined

# %%
even=[2,4,6,8]
anothereven=even
anothereven.sort(reverse=True)    #it is K sensitive    not true but True
print(anothereven)     # when we updated new variable that is linked with list  then previous list will also chaged 
print(even)

print(anothereven is even)
# Out:
# [8, 6, 4, 2]
# [8, 6, 4, 2]
# True

# %%
print(even)
print(odd)
# Out:
# [8, 6, 4, 2]
# [1, 3, 5, 7]

# %%
number=[even,odd]
print(number)
# Out:
# [[8, 6, 4, 2], [1, 3, 5, 7]]

# %%
#number list contain 2 list
for i in number:
    print(i)
# Out:
# [8, 6, 4, 2]
# [1, 3, 5, 7]

# %%
for i in number:      #will print both list in horizontal
    print(i)
    
    for j in i:    # will print each dat in vertical for list
        print(j)
# Out:
# [8, 6, 4, 2]
# 8
# 6
# 4
# 2
# [1, 3, 5, 7]
# 1
# 3
# 5
# 7

# %%
menu=[]
menu.append(["ajay","amit"])
menu.append(["anurag","amit"])
menu.append(["anurag","amit","spam"])
print(menu)

for meal in menu:
    if "spam" in meal:
        print("we got spam")
    else:
        print("data clear")
print("++++++++")
for meal in menu:
    if "spam" not in meal:
        
        for i in meal:
            print(i)
# Out:
# [['ajay', 'amit'], ['anurag', 'amit'], ['anurag', 'amit', 'spam']]
# data clear
# data clear
# we got spam
# ++++++++
# ajay
# amit
# anurag
# amit

# %%
# iterration   ,what logic
strint="12345"
my_string=iter(strint)
print(my_string)     # output would be the menmory location of string
print(next(my_string))  # iteration through index value
print(next(my_string))
print(next(my_string))
print(next(my_string))
print(next(my_string))   #5
print(next(my_string))   # now data is cmpleted  at 5 but still we wrote it thats why it is giving error
# Out:
# ...
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-71-52df4368cfa7> in <module>
#       8 print(next(my_string))
#       9 print(next(my_string))
# ---> 10 print(next(my_string))
#
# StopIteration:

# %%
string="345"
for i in string:
    print(i)
for j in iter(string):      # python automatically use iter inplicity when we writeprevious code
    print(j)

# %%
my_listagain=["m","t","w","th","f","sa","sun"]
new=iter(my_listagain)

for i in range(0,len(my_listagain)):   #  len will calcuate lenfth
    nextitem=next(new)    # next function work with which hold iter value
    print(nextitem)
print("another way to print without iteration function")
for j in my_listagain:
    print(j)
# Out:
# m
# t
# w
# th
# f
# sa
# sun
# another way to print without iteration function
# m
# t
# w
# th
# f
# sa
# sun
