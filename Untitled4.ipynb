# %%
print("day4     slice step")
string ="abcdfergjkyiuo"
print(string[0:4:2])
# Out:
# day4     slice step
# ac

# %%
print(string[0:4:3])
# Out:
# ad

# %%
print(string[0:4:4])
# Out:
# a

# %%
print(string[0:4:0])   # this slic step very important
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c9c2fbaffeb5> in <module>
# ----> 1 print(string[0:4:0])
#
# ValueError: slice step cannot be zero

# %%
print(string[0:4:-1])

# %%
number="1111,3333,5555"
print(number)
# Out:
# 1111,3333,5555

# %%
prinnt(number[1:4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2f06b495c1b0> in <module>
# ----> 1 prinnt(number[1:4])
#
# NameError: name 'prinnt' is not defined

# %%
print(number[1:4])
# Out:
# 111

# %%
print(number[1::4])
# Out:
# 13,5

# %%
print(number[1::1])
# Out:
# 111,3333,5555

# %%
print(number[1::2])
# Out:
# 1133,55

# %%
print(number)
print(number[0::0])
# Out:
# 1111,3333,5555
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-71d16825afe4> in <module>
#       1 print(number)
# ----> 2 print(number[0::0])
#
# ValueError: slice step cannot be zero

# %%
print(number)
print(number[0::1])
# Out:
# 1111,3333,5555
# 1111,3333,5555

# %%
print(number)
print(number[0::2])
# Out:
# 1111,3333,5555
# 11,3355

# %%
# need to understand this thing later 
aa="qwertyuiopasdfgjkl"
print(aa[12:2])

# %%
aa="qwertyuiopasdfgjkl"
print(aa[12:2:-2])
# Out:
# daout

# %%
aa="qwertyuiopasdfgjkl"
print(aa[17:0:-2])
# Out:
# ljfspiyrw

# %%
aa="qwertyuiopasdfgjkl"
print(aa[17:0:2])

# %%
aa="qwertyuiopasdfgjkl"
print(aa[17:0:-1])
# Out:
# lkjgfdsapoiuytrew

# %%
#we need to remember that
aa="qwertyuiopasdfgjkl"
print(aa[::-1])
# Out:
# lkjgfdsapoiuytrewq

# %%
aa="qwertyuiopasdfgjkl"
print(aa[::-2])
# Out:
# ljfspiyrw

# %%
aa="qwertyuiopasdfgjkl"
print(aa[::-3])
# Out:
# lgsoye

# %%
aa="qwertyuiopasdfgjkl"
print(aa[::-4])
# Out:
# lfpyw

# %%
a1="abcefghijklmnopqrstuvwxyz"
print(a1[17:15])

# %%
a1="abcefghijklmnopqrstuvwxyz"
print(a1[17:15:-12])
# Out:
# s

# %%
a1="abcefghijklmnopqrstuvwxyz"
print(a1[17:15:-1])
# Out:
# sr

# %%
a1="abcefghijklmnopqrstuvwxyz"
print(a1[17:15:-2])
# Out:
# s

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[17:15:-3])
# Out:
# r

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[17:15:-2])
# Out:
# r

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[17:15:-1])
# Out:
# rq

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[4:0:-1])
# Out:
# edcb

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[4::-1])
# Out:
# edcba

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[4:0:-1])
print(length(a1))
# Out:
# edcb
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-35021744f9c7> in <module>
#       1 a1="abcdefghijklmnopqrstuvwxyz"
#       2 print(a1[4:0:-1])
# ----> 3 print(length(a1))
#
# NameError: name 'length' is not defined

# %%
print(len(a1))
# Out:
# 26

# %%
a1="abcdefghijklmnopqrstuvwxyz"
print(a1[26:16:-1])
# Out:
# zyxwvutsr

# %%
# -1 is for printing in reverse order
a="he"
b="is"
print(a+b)
print("he" "is")
# Out:
# heis
# heis

# %%
print(a*5)
print("he"*5)
# Out:
# hehehehehe
# hehehehehe

# %%
print(a *(5+5))
print(a *5+"5")
# Out:
# hehehehehehehehehehe
# hehehehehe5

# %%
today="friday"
print("fri" in today)
print("fri"in "friday")
# Out:
# True
# True
