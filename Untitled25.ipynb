# %%
# Out:
# continue different types of creating dataframes in pandas
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f5ee63b8ad0b> in <module>
#       1 print("continue different types of creating dataframes in pandas")
# ----> 2 import pandas as pd
#       3 weather_data=[{ 'name':'Ajay','class':'bca','age':22},
#       4    { 'name':'Amit','class':'MCA','age':24} ]
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     194 # GH 27101
#     195 # TODO: remove Panel compat in 1.0
# --> 196 if pandas.compat.PY37:
#     197
#     198     def __getattr__(name):
#
# AttributeError: module 'pandas' has no attribute 'compat'

# %%
https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
# Reading and writing in Excel and CSV files
import pandas as pd
print("hi")
df=pd.read(r"C:\Users\Ajay\Desktoppandas_import.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-022c4871ec10> in <module>
#       1 # Reading and writing in Excel and CSV files
# ----> 2 import pandas as pd
#       3 print("hi")
#       4 df=pd.read(r"C:\Users\Ajay\Desktoppandas_import.xlsx")
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     194 # GH 27101
#     195 # TODO: remove Panel compat in 1.0
# --> 196 if pandas.compat.PY37:
#     197
#     198     def __getattr__(name):
#
# AttributeError: module 'pandas' has no attribute 'compat'
