# %%
print("new day 7")
# Out:
# new day 7

# %%
number="9,99,99999,098333"
newnumber=''
for char in number:
    if char in'0123456780':
        newnumber=newnumber+char+newnumber
        print(newnumber)
# Out:
# 0
# 080
# 0803080
# 080308030803080
# 0803080308030803080308030803080

# %%
print(type(newnumber))
print(newnumber)
# Out:
# <class 'str'>
# 08333

# %%
totalint=int(newnumber)

# %%
print(totalint)
# Out:
# 8333

# %%
avenger=["hulk","ironman","spiderman","captionamerica","antman"] # i have use list dat structure[]
for i in avenger:
    print("my name is "+i,end='')
# Out:
# my name is hulkmy name is ironmanmy name is spidermanmy name is captionamericamy name is antman

# %%
avenger=("hulk","ironman","spiderman","captionamerica","antman") # i have use set data structure()
for i in avenger:
    print("my name is "+i,end='')
# Out:
# my name is hulkmy name is ironmanmy name is spidermanmy name is captionamericamy name is antman

# %%
for i in range(0,100,20):
    print(i)
# Out:
# 0
# 20
# 40
# 60
# 80

# %%
for i in range(1,13):
    for j in range(1,13):
        print("{0} * {1} = {2}".format(i,j,i*j),end='\t') # every single result will tab
    print("next table as below")
# Out:
# 1 * 1 = 1	1 * 2 = 2	1 * 3 = 3	1 * 4 = 4	1 * 5 = 5	1 * 6 = 6	1 * 7 = 7	1 * 8 = 8	1 * 9 = 9	1 * 10 = 10	1 * 11 = 11	1 * 12 = 12	next table as below
# 2 * 1 = 2	2 * 2 = 4	2 * 3 = 6	2 * 4 = 8	2 * 5 = 10	2 * 6 = 12	2 * 7 = 14	2 * 8 = 16	2 * 9 = 18	2 * 10 = 20	2 * 11 = 22	2 * 12 = 24	next table as below
# 3 * 1 = 3	3 * 2 = 6	3 * 3 = 9	3 * 4 = 12	3 * 5 = 15	3 * 6 = 18	3 * 7 = 21	3 * 8 = 24	3 * 9 = 27	3 * 10 = 30	3 * 11 = 33	3 * 12 = 36	next table as below
# 4 * 1 = 4	4 * 2 = 8	4 * 3 = 12	4 * 4 = 16	4 * 5 = 20	4 * 6 = 24	4 * 7 = 28	4 * 8 = 32	4 * 9 = 36	4 * 10 = 40	4 * 11 = 44	4 * 12 = 48	next table as below
# 5 * 1 = 5	5 * 2 = 10	5 * 3 = 15	5 * 4 = 20	5 * 5 = 25	5 * 6 = 30	5 * 7 = 35	5 * 8 = 40	5 * 9 = 45	5 * 10 = 50	5 * 11 = 55	5 * 12 = 60	next table as below
# 6 * 1 = 6	6 * 2 = 12	6 * 3 = 18	6 * 4 = 24	6 * 5 = 30	6 * 6 = 36	6 * 7 = 42	6 * 8 = 48	6 * 9 = 54	6 * 10 = 60	6 * 11 = 66	6 * 12 = 72	next table as below
# ...

# %%
list=["milk","egg","onion","spam","burger"]
for i in list:
    if i =="spam":
        continue
    else:
        print(i)
# Out:
# milk
# egg
# onion
# burger

# %%
list=["milk","egg","onion","spam","burger"]
for i in list:
    if i =="spam":                 # see the output both
        break                      # break get out of for loop
    else:
        print(i)
# Out:
# milk
# egg
# onion

# %%
list=["milk","egg","onion","spam","burger"]
for i in list:
    if i in "spam":
        continue
    else:
        print(i)
# Out:
# milk
# egg
# onion
# burger

# %%
list=["milk","egg","onion","spam","burger"]

for i in list:
    if i=="spam":
        nasty_food=i
            
if nasty_food:
    print("i got spam result")
# Out:
# i got spam result
