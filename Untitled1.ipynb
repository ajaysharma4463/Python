# %%
print('hi')
# Out:
# hi

# %%
a=3
a
# Out:
# 3

# %%
print("hi again ")
# Out:
# hi again

# %%
print('hi")
# Out:
#   File "<ipython-input-6-cd7212d0db17>", line 1
#     print('hi")
#                ^
# SyntaxError: EOL while scanning string literal

# %%
print('hi")
# Out:
#   File "<ipython-input-7-cd7212d0db17>", line 1
#     print('hi")
#                ^
# SyntaxError: EOL while scanning string literal

# %%
print(hello+a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5327865956b6> in <module>
# ----> 1 print(hello+a)
#
# NameError: name 'hello' is not defined

# %%
hello("hello"+2+a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5b47e6ffb308> in <module>
# ----> 1 hello("hello"+2+a)
#
# NameError: name 'hello' is not defined

# %%
hello("hello"+a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-43f66e3e712a> in <module>
# ----> 1 hello("hello"+a)
#
# NameError: name 'hello' is not defined

# %%
print("ello"+a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1f93c63e624b> in <module>
# ----> 1 print("ello"+a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("hello"+"hellotwice")
# Out:
# hellohellotwice

# %%
print("heelo"+""+"hello3")
# Out:
# heelohello3

# %%
print("heelo"+"      "+"hello3")
# Out:
# heelo      hello3

# %%
print("heelo"+" "+"hello3")
# Out:
# heelo hello3

# %%
print(a)
# Out:
# 3

# %%
print(a+1)
# Out:
# 4

# %%
print(a/3+"will it work")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2f045e5baaa0> in <module>
# ----> 1 print(a/3+"will it work")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print(a*10)
# Out:
# 30

# %%
print("this is string literal ")
# line is full of string literal

# %%
print("")
print(2+2+2)
print()
print("the end ")
# Out:
# 6
#
# the end

# %%
print(print("hi"))
# Out:
# hi
# None

# %%
print(print(print(a)))
# Out:
# 3
# None
# None

# %%
print("print(a)")
# Out:
# print(a)

# %%
    print("hi","will it print","again")
    print("hi"+"will it print"+"again")
# Out:
# hi will it print again
# hiwill it printagain

# %%
# WATCH THE DIFFERENCE BETWEENTWO
print(2<3)
# Out:
# True

# %%
print(2<3&3<4)
# Out:
# True

# %%
print(2<3&3>4)
# Out:
# False

# %%
print(2<3|3<2)
# Out:
# False

# %%
print(2=2)
# Out:
#   File "<ipython-input-31-e23e4f87a2b3>", line 1
#     print(2=2)
#          ^
# SyntaxError: keyword can't be an expression

# %%
print(if 2<3 :
     print("true")
     else:
     print(""no))
# Out:
#   File "<ipython-input-32-8e21b46d8d53>", line 1
#     print(if 2<3 :
#            ^
# SyntaxError: invalid syntax

# %%
if 2<3 :
     print("true")
     else:
     print(""no)
# Out:
#   File "<ipython-input-33-104327eae0b4>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
if a<2:
    print(a)

# %%
a=4,b=10
a
b
# Out:
#   File "<ipython-input-35-589ad24f540a>", line 1
#     a=4,b=10
#      ^
# SyntaxError: can't assign to literal

# %%
a=4
b=10
a
b
# Out:
# 10

# %%
a
# Out:
# 4

# %%
a,4
# Out:
# (4, 4)

# %%
a,b
# Out:
# (4, 10)

# %%
a,3+3,b
# Out:
# (4, 6, 10)

# %%
print("will it print single quotes'see'")
# Out:
# will it print single quotes'see'

# %%
print('will it print"double quotes"')
# Out:
# will it print"double quotes"

# %%
print("hi")
# Out:
# hi

# %%
gerting='hello'
name='ajay'
print(ajay,greting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-35cc57c91ad3> in <module>
#       1 gerting='hello'
#       2 name='ajay'
# ----> 3 print(ajay,greting)
#
# NameError: name 'ajay' is not defined

# %%
print(name,greting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-64fe8c395db0> in <module>
# ----> 1 print(name,greting)
#
# NameError: name 'greting' is not defined

# %%
print(name,gerting)
# Out:
# ajay hello

# %%
print(name,gerting)
print(name+gerting)
# Out:
# ajay hello
# ajayhello

# %%
name
# Out:
# 'ajay'

# %%
name=input("enter name from keyword,wil it change the existing data")
# Out:
# enter name from keyword,wil it change the existing dataakshay

# %%
name
# Out:
# 'akshay'

# %%
name=input("enter new name"+:)
# Out:
#   File "<ipython-input-51-1949bef08769>", line 1
#     name=input("enter new name"+:)
#                                 ^
# SyntaxError: invalid syntax

# %%
name=input("enter new name:")
if name='anjali':
    print("data is equal")
# Out:
#   File "<ipython-input-52-56cf9f719a05>", line 2
#     if name='anjali':
#            ^
# SyntaxError: invalid syntax

# %%
name=input("enter new name:")
print(name+'Sister')
# Out:
# enter new name:anjali
# anjaliSister

# %%
name=input("enter new name:")
print(name , 'Sister')
# Out:
# enter new name:anajli
# anajli Sister

# %%
input("enter")
# Out:
# enter3
# '3'

# %%
print(input('hello :'')
# Out:
#   File "<ipython-input-56-a4ccebb7900d>", line 1
#     print(input('hello :'')
#                            ^
# SyntaxError: EOL while scanning string literal

# %%
input('hello :')
# Out:
# hello :4
# '4'

# %%
input("enter your anme")
# Out:
# enter your anmeajay
# 'ajay'
