# %%
# python 7 tutorial
print("hi")
# Out:
# hi

# %%
x=False
if x:
    print("x is true")
else:
    print("i have not use inverted comma")
# Out:
# i have not use inverted comma

# %%
x=input("enter your name")
if x:
    print(" your name is '{0}'".format(x))
else:
    print("you have not put anything")
# Out:
# enter your name
# you have not put anything

# %%
print(True)
print("True")
print(not True)
print(False)
print(not False)
print("lok down")
print(not 0)
print(not 1)
# Out:
# True
# True
# False
# False
# True
# lok down
# True
# False

# %%
age=int(input("enter your age"))
if not(age<18):
    print("you are eligible")
else:
    print("come later")
# Out:
# enter your age12
# come later

# %%
x="ajaysharma"
y="ajay"
if x in y:
    print("i see ajaysharma in both literal")
else:
    print("sorry")
# Out:
# sorry

# %%
x="ajaysharma"
y="ajay"
if x not in y:
    print("i see ajaysharma in both literal")
else:
    print("sorry")
# Out:
# i see ajaysharma in both literal

# %%
number="2,22,345,:,23467"
for i in range(0,len(number)): # len function read the the charater of string
    print(number[i])
# Out:
# 2
# ,
# 2
# 2
# ,
# 3
# 4
# 5
# ,
# :
# ,
# 2
# 3
# 4
# 6
# 7

# %%
number="2,22,345,:,23467"
for i in range(0,len(number)): # len function read the the charater of string
    if number[i] in '0123457':
        print(number[i],end="")  # end=""   becasue it will show the output in sequence order otherwise it will show in verical
# Out:
# 2223452347
